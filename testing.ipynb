# %% [markdown]
# ### Importing Model and functions:

# %%
import os
from scipy.io import loadmat
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from support_functions import relabel, predict_image, master_plot, validate_segmentation

# %%
os.listdir(os.path.join(os.getcwd(), "saved_model"))
# Out:
# ['generator.h5']

# %%
import h5py
f = h5py.File(os.path.join(r'saved_model','generator.h5'))

# %%
f
# Out:
# <HDF5 file "generator.h5" (mode r+)>

# %%
model = tf.keras.models.load_model(os.path.join(r'saved_model','generator.h5'))
path = os.path.join(os.getcwd(), "dataset/annotations")
all_files = os.listdir(path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-0f3261d1a3a0> in <module>
# ----> 1 model = tf.keras.models.load_model(os.path.join(r'saved_model','generator.h5'))
#       2 path = os.path.join(os.getcwd(), "dataset/annotations")
#       3 all_files = os.listdir(path)
#
# ~\Anaconda3\envs\super\lib\site-packages\tensorflow_core\python\keras\saving\save.py in load_model(filepath, custom_objects, compile)
#     144   if (h5py is not None and (
#     145       isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 146     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     147
#     148   if isinstance(filepath, six.string_types):
#
# ~\Anaconda3\envs\super\lib\site-packages\tensorflow_core\python\keras\saving\hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
# ...

# %% [markdown]
# ### Training the model:

# %%
gan = Pix2Pix()
# Out:
# 1/1 [==============================] - 1s 990ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 0/1] [Batch 0/803] [D loss: 3.591818, acc:  35%] [G loss: 78.458672] time: 0:00:07.872606
# ...
# 1/1 [==============================] - 1s 712ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 0/1] [Batch 1/803] [D loss: 46.340429, acc:  56%] [G loss: 72.609070] time: 0:00:16.189822
# 1/1 [==============================] - 1s 841ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 0/1] [Batch 2/803] [D loss: 11.792789, acc:  43%] [G loss: 67.415161] time: 0:00:22.768553
# ...

# %%
from testing_function import random_test
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-46d0226ffc55> in <module>
# ----> 1 from testing_function import random_test
#
# ~\Desktop\pix2pix\testing_function.py in <module>
#       9
#      10
# ---> 11 model = tf.keras.models.load_model('saved_model\generator.h5')
#      12 path = os.path.join(os.getcwd(), "dataset/annotations")
#      13 all_files = os.listdir(path)
#
# ~\Anaconda3\envs\super\lib\site-packages\tensorflow_core\python\keras\saving\save.py in load_model(filepath, custom_objects, compile)
#     144   if (h5py is not None and (
#     145       isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 146     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     147
#     148   if isinstance(filepath, six.string_types):
#
# ...

# %% [markdown]
# ### Testing the model on a random sample:

# %%
random_test()
# Out:
# 1/1 [==============================] - 1s 937ms/step
# Here's the original segmentation
# Here's our predicted segmentation
